# %% [markdown]
# <a href="https://colab.research.google.com/github/kumarchandan/Codein-Machine-Learning/blob/main/Clustering/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Clustering
#
# #### KMeans

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score

# %%
raw_df = pd.read_csv('https://raw.githubusercontent.com/instituteofai/ML-101/master/Datasets/credit_card.csv')
raw_df.head()
# Out:
#   CUST_ID      BALANCE  ...  PRC_FULL_PAYMENT  TENURE
# 0  C10001    40.900749  ...          0.000000      12
# 1  C10002  3202.467416  ...          0.222222      12
# 2  C10003  2495.148862  ...          0.000000      12
# 3  C10004  1666.670542  ...          0.000000      12
# 4  C10005   817.714335  ...          0.000000      12
#
# [5 rows x 18 columns]

# %%
raw_df = raw_df.drop('CUST_ID', axis = 1) 
raw_df.fillna(method ='ffill', inplace = True) 
raw_df.head(2)
# Out:
#        BALANCE  BALANCE_FREQUENCY  ...  PRC_FULL_PAYMENT  TENURE
# 0    40.900749           0.818182  ...          0.000000      12
# 1  3202.467416           0.909091  ...          0.222222      12
#
# [2 rows x 17 columns]

# %% [markdown]
# Data preprocessing

# %%
# Standardize data
scaler = StandardScaler() 
scaled_df = scaler.fit_transform(raw_df)

# %%
scaled_df
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.3053336 ,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08714014,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10010994,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.32935392,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34057185,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.32688396,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# We can use either scaler or normalization, but to calculate cosine_similarity_score we need to use L2 normalization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Normalizing the Data 
normalized_df = normalize(scaled_df) 
# Converting the numpy array into a pandas DataFrame 
normalized_df = pd.DataFrame(normalized_df)
normalized_df
# Out:
#             0         1         2   ...        14        15        16
# 0    -0.312038 -0.106331 -0.181129  ... -0.130160 -0.224036  0.153753
# 1     0.219928  0.037539 -0.131224  ...  0.024353  0.065458  0.100798
# 2     0.126684  0.146785 -0.030505  ... -0.028363 -0.148900  0.102189
# 3     0.020571 -0.426063  0.097223  ... -0.041942 -0.220185  0.151110
# 4    -0.151630  0.218959 -0.195282  ... -0.110323 -0.222114  0.152435
# ...        ...       ...       ...  ...       ...       ...       ...
# 8945 -0.146906  0.103137 -0.066350  ... -0.068374  0.235693 -0.820733
# 8946 -0.151150  0.105477 -0.067009  ... -0.069925 -0.106997 -0.839354
# 8947 -0.156989 -0.039327 -0.085230  ... -0.069834  0.069801 -0.874162
# 8948 -0.154334 -0.038414 -0.097250  ... -0.070536  0.068181 -0.853872
# 8949 -0.115217 -0.178896  0.008481  ... -0.065777 -0.105754 -0.829606
#
# [8950 rows x 17 columns]

# %%
# Reducing the dimensions of the data 
pca = PCA(n_components = 2) 
pca = pca.fit(normalized_df) 
X_principal = pca.transform(normalized_df)
X_principal = pd.DataFrame(X_principal) 
X_principal.columns = ['P1', 'P2'] 
  
X_principal.head(10)
# Out:
#          P1        P2
# 0 -0.489949 -0.679976
# 1 -0.519099  0.544827
# 2  0.330633  0.268879
# 3 -0.481656 -0.097611
# 4 -0.563512 -0.482506
# 5  0.336076 -0.235098
# 6  0.756178  0.388880
# 7  0.576473 -0.261946
# 8 -0.185031 -0.254403
# 9 -0.217363 -0.124388

# %%
plt.scatter(X_principal['P1'], X_principal['P2'])

# %% [markdown]
# K-Means clustering

# %%
sse = {}
for k in range(1, 10):
    kmeans = KMeans(n_clusters=k, max_iter=1000).fit(X_principal)
    sse[k] = kmeans.inertia_ # Inertia: Sum of distances of samples to their closest cluster center

# %%
sse
# Out:
# {1: 4151.90003040492,
#  2: 2119.498732229855,
#  3: 1317.0006120192543,
#  4: 927.9178099104362,
#  5: 725.4484729872116,
#  6: 602.8212220771567,
#  7: 514.1336319941261,
#  8: 433.9906274900165,
#  9: 380.5262910185432}

# %%
plt.figure()
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(X_principal)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Visualizing the clustering 
plt.scatter(X_principal['P1'], X_principal['P2'],  
           c = KMeans(n_clusters = 4).fit_predict(X_principal), cmap =plt.cm.winter) 
plt.show()

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.47839699, -0.29063086],
#        [ 0.41961731, -0.31817664],
#        [ 0.56727275,  0.33593225],
#        [-0.44332515,  0.51756131]])

# %%
normalized_df.iloc[0]
# Out:
# 0    -0.312038
# 1    -0.106331
# 2    -0.181129
# 3    -0.152156
# 4    -0.148808
# 5    -0.198985
# 6    -0.343796
# 7    -0.289304
# 8    -0.301518
# 9    -0.287892
# 10   -0.202942
# 11   -0.217975
# 12   -0.409413
# 13   -0.225497
# 14   -0.130160
# 15   -0.224036
# 16    0.153753
# Name: 0, dtype: float64

# %%
input = pca.transform(np.reshape(np.array(normalized_df.iloc[0]), (-1, 17)))

# %%
input
# Out:
# array([[-0.48994913, -0.67997621]])

# %%
label = kmeans.predict(input)

print(label)
# Out:
# [0]
